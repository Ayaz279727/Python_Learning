# %%
# import library
import pandas as pd
import numpy
import seaborn as sns
import matplotlib.pyplot as plt

jammat = pd.read_csv("assignment_data.csv")
jammat

sns.countplot(x='Age',data=jammat, order=['jan-15','16-20','21-25','26-30','31-35','36-40','41-45','46-60'])
plt.show()
