# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv("Chilla_data2_plotly.csv")
# df = px.data.iris()
fig = px.scatter(df, x="Age (years)-Float/Int", y="How many hours you code a day? (int) e.g: 5,4,3", color="Qualification_completed", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
fig.show()
# Out:
# <div>
#
#
#             <div id="a02e2e4b-b7ee-4e3e-b745-1d3ce2b4644b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a02e2e4b-b7ee-4e3e-b745-1d3ce2b4644b")) {
#                     Plotly.newPlot(
#                         'a02e2e4b-b7ee-4e3e-b745-1d3ce2b4644b',
# ...

# %%
import plotly.express as px
#df = px.data.iris()
import pandas as pd
df = pd.read_csv("Chilla_data2_plotly.csv")

fig = px.scatter_matrix(df, dimensions=["Your Weight in kg? (float)", "Height in cm? Freelancer- (Float)", "How many hours you code a day? (int) e.g: 5,4,3", "Light kitni der band hti hy? int"], color="What are you?")
fig.show()
# Out:
# <div>
#
#
#             <div id="9c11e80b-8318-4063-8db1-47d88e5c84b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9c11e80b-8318-4063-8db1-47d88e5c84b6")) {
#                     Plotly.newPlot(
#                         '9c11e80b-8318-4063-8db1-47d88e5c84b6',
# ...

# %%
import plotly.express as px
import pandas as pd

df=pd.read_csv("Chilla_data2_plotly.csv")
df.head(2)
# Out:
#   Gender  Location    Age Qualification_completed    field_of_study  \
# 0   Male  Pakistan  36-40                 Masters  Natural Sciences
# 1   Male  Pakistan  26-30               Bachelors             CS/IT
#
#       Purpose_for_chilla What are you? Blood group  \
# 0  to boost my skill set     Unemplyed          B+
# 1  to boost my skill set       Student          B+
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
#
#   Your favorite programming language? Marital Status? Are you Vaccinated?  \
# 0                              Python             Yes                 Yes
# 1                              Python              No                 Yes
#
#   Where do you live? Research/Working experience (Float/Int) years  \
# 0              Urbun                                          5.00
# 1              Urbun                                          1.00
#
# ...
