# %% [markdown]
# # Import libraries
# Seaborn automaticaly installed in jupyter notebook
# - numpy
# - scipy
# - pandas
# - matplotlib

# %%
# import library
import seaborn as sns
import matplotlib.pyplot as plt

# load data set
phool =sns.load_dataset("iris")
phool

# draw a line plot (alway create b/w two numaric values)
sns.lineplot(x='sepal_length',y='sepal_width',data=phool)
plt.show()

# %% [markdown]
# ## adding title

# %%
# import library
import seaborn as sns
import matplotlib.pyplot as plt

# load data set
phool =sns.load_dataset("iris")
phool

# draw a line plot (alway create b/w two numaric values)
sns.lineplot(x='sepal_length',y='sepal_width',data=phool)
plt.title("Phoolo ka plot")
plt.show()

# %% [markdown]
# ## adding Limits

# %%
# import library
import seaborn as sns
import matplotlib.pyplot as plt

# load data set
phool =sns.load_dataset("iris")
phool

# draw a line plot (alway create b/w two numaric values)
sns.lineplot(x='sepal_length',y='sepal_width',data=phool)
plt.title("Phoolo ka plot")
plt.xlim(2)
plt.ylim(2)

plt.show()

# %% [markdown]
# ## set styles
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks

# %% [markdown]
# ### Assignment no 2

# %%
# import library
import seaborn as sns
import matplotlib.pyplot as plt

#answer of assignment lecture 11
sns.set_style(style=None, rc= None)

# load data set
phool =sns.load_dataset("iris")
phool

# draw a line plot (alway create b/w two numaric values)
sns.lineplot(x='sepal_length',y='sepal_width',data=phool)

plt.title("Phoolo ka plot")

sns.set_style("darkgrid")

plt.show()

# %% [markdown]
# ## size of figure

# %%
# import library
import seaborn as sns
import matplotlib.pyplot as plt

# load data set
phool =sns.load_dataset("iris")

# change figure
plt.figure(figsize=(4,4))

# draw a line plot (alway create b/w two numaric values)
sns.lineplot(x='sepal_length',y='sepal_width',data=phool)
plt.title("Phoolo ka plot")


plt.show()
